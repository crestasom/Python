# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
# %matplotlib inline

# %%
X=np.linspace(-1,1,101)
#noise=np.random.randn(*X.shape)*0.33
plt.plot(X)
