# %%
import random
from scipy.spatial import distance

def dist(a,b):
    return distance.euclidean(a,b)

class ScarpyKNN():
    def fit(self,X_train,Y_train):
        self.Y_train=Y_train
        self.X_train=X_train
    def predict(self,X_test):
        predictions=[]
        for row in X_test:
            print('\n')
            label=self.closet(row)
            predictions.append(label)
        return predictions
    def closet(self,row):
        best_dist=dist(row,self.X_train[0])
        best_index=0
        for i in range(1,len(self.X_train)):
            print(best_dist)
            distance1=dist(row,self.X_train[i])
            if distance1<best_dist:
                best_dist=distance1
                best_index=i
            return self.Y_train[best_index]

# %%
import numpy as np
import matplotlib.pyplot as plt

greyhounds=500
labs=500
grey_height=28+4 * np.random.randn(greyhounds)
labs_height=24+4 * np.random.randn(labs)
#print(grey_height)
# print(grey_height.max())
# print(grey_height.min())
# print(labs_height.max())
# print(labs_height.mean())
plt.hist([grey_height,labs_height],stacked=True,color=['r','b'])
plt.show()

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

iris=datasets.load_iris();
x=iris['data']
y=iris['target']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5)
print('Y_train',y_train)

# my_classifier=tree.DecisionTreeClassifier()
# my_classifier=KNeighborsClassifier()
my_classifier=ScarpyKNN()

my_classifier.fit(x_train,y_train)
prediction=my_classifier.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# Y_train [2 0 0 1 1 2 1 1 2 0 1 0 1 2 0 1 1 2 2 2 1 1 2 1 0 0 0 1 1 0 1 2 2 2 2 2 1
#  1 0 0 2 2 1 0 1 1 1 0 2 0 0 2 0 0 0 0 1 2 2 0 0 0 1 0 2 0 0 0 0 0 0 2 1 2
#  2]
#
#
# 4.959838707054898
#
#
# 1.8165902124584947
#
#
# 2.660826939130014
#
#
# 2.8722813232690143
#
#
# 5.33572862878164
#
#
# 4.969909455915671
#
#
# 1.4798648586948744
#
#
# 1.1180339887498953
#
#
# 2.3194827009486403
#
#
# 5.472659317004851
#
#
# 5.046781152378217
#
#
# 2.2803508501982757
#
#
# 1.352774925846868
#
#
# 5.5677643628300215
#
#
# 4.935585071701226
#
#
# 0.4242640687119289
#
#
# 1.374772708486752
#
#
# 5.187484939737175
#
#
# 0.9327379053088815
#
#
# 2.7386127875258306
#
#
# 3.6110940170535577
#
#
# 1.7175564037317672
#
#
# 1.8439088914585775
#
#
# 1.6881943016134129
#
#
# 5.242136968832463
#
#
# 1.1489125293076061
#
#
# 0.5000000000000002
#
#
# 2.535744466621193
#
#
# 1.9157244060668015
#
#
# 0.7416198487095665
#
#
# 1.452583904633395
#
#
# 1.4999999999999998
#
#
# 2.6814175355583845
#
#
# ...
